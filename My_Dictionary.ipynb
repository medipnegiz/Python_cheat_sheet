# %% [markdown]
# ### 👉 Bu dosya **Mahmut Edip Negiz** tarafindan olusturulmustur.
# ### 👉 iletisim icin *mahmutedipnegiz@gmail.com*

# %% [markdown]
# ### **STRING IFADE KOD KULLANIMLARI**

# %%
konu = '  Havalar iyice, sogudu Murat beyyy  '
text = 'Muratterzi'
print('1:', konu.swapcase())                        #   büyük ve küyük harfleri tam tersi yapar
print('2:', konu.upper())                           #   hepsini büyük yapar
print('3:', konu.lower())                           #   hepsini kücük yapar
print('4:', konu.casefold())                        #   hepsini kücük yapar
print('5:', konu.capitalize())                      #   Sadece satir basi büyük olur
print('6:', konu.title())                           #   Tüm kelimeler büyük ile baslar
print('7:', konu.replace('r', 'g',2))               #   cümle icinden istenilen harfi baska bir harf ile degistirir.(sayi kac kere degistirecegini belirler)
print('8:', konu.count('a', 5, 25))                 #   cümlede istenilen harften kac tane var onu sayar veya kac karakter var onu sayar. (start ve stop indeksi verilebilir)
print('9:', konu.startswith('Hava', 2))             #   cümle istenilen kelimeler ile basliyorsa " True veya False " verir. (start ve stop indeksi verilebilir)
print('10:', konu.endswith('bey', 0, 32))           #   cümle istenilen kelimeler ile bitiyorsa " True veya False " verir. (start ve stop indeksi verilebilir)
print('11:', konu.startswith('i', 8))               #   cümle icinden konum vererek harf buldurulur " True ve False " alinir
print('12:', konu.strip(' y '))                     #   cümlenin iki tarafindaki bosluklari veya icindeki harflari kaldirir
print('13:', konu.lstrip(' Ha'))                    #   soldan istedigimiz kelimeleri siler (bosluklar önemli) "kac tane o kelimeden bulursa siler"
print('14:', konu.rstrip('ey '))                    #   sagdan istedigimiz kelimeri siler (bosluklar önemli) "kac tane o kelimeden bulursa siler"
print('15:', konu.find('a'))                        #   cümle icinden istenilen harfin konumunu soldan arar ve ilk buldugu degeri verir
print('16:', konu.rfind('t'))                       #   cümle icinden istenilen harfin konumunu sagdan arar ve ilk buldugu degeri verir
print('17:', text.index('a'))                       #   cümle icinden istenilen harfin konumunu verir (büyük kücük harf duyarli). (0 dan baslar)
print('18:', *konu)                                 #   " * " harflerin arasina bosluk ekler
print('19:', 'iyi' in konu)                         #   icinde istenilen harf var mi diye bakar (True ve False verir)
print('20:', '@' not in konu)                       #   icinde istenilen harf yok mu diye bakar (True ve False verir)
print('21:', ' # '.join(konu))                      #   her karakter sonrasina istenilen karakteri ekler.
print('22:', konu.center(46, '+'))                  #   istenilen karakter sayisi dolana kadar sola ve saga ekleme yapar
print('23:', konu.ljust(40, '.'))                   #   yaziyi sola yaslar ve saga istenilen sayi kadar karakter ile doldurur.
print('24:', konu.rjust(50, '/'))                   #   yaziyi saga yaslar ve sola istenilen sayi kadar karakter ile doldurur.
print('25:', konu.zfill(45))                        #   yazinin basina istenilen sayi kadar "0" sifir ekler      
print('26:', konu.split('a'))                       #   ayristirma yapiyor, icine girilen karakteri kaldiriyor ve virgül ile ayiriyor.
print('27:', konu.split(',')[0])                    #   icine girilen karakterden itibaren ayirdik ve indis vererek yazdirdik.
print('28:', min(konu), max(konu))                  #   ASCII kod tablosuna göre en son ve ilk harfi yazdirir
print('29:', text.isalpha())                        #   tamami harflerden mi olusuyor diye sorgulama yaptik       
print('30:', text.isdigit())                        #   tamami rakamlardan mi olusuyor diye sorgulama yaptik
print('31:', konu.isalnum())                        #   rakam ve harften mi olusuyor diye sorgulama yaptik. (Özel simgeleri kabul etmez)

# %%
print('1:', ' Oyun ', ' sahasi ', ' kapali ', sep='+')                   #   aralara istenilen karakterleri ekler
print('2:', ' Oyun ', ' sahasi ', ' kapali ', end='$')                   #   sona istenilen karakteri ekler (normalde "print" alt satira inecekken yanina yazar)
print('3:', '\t', ' Oyun ', ' sahasi ', ' kapali')                       #   " \t " tab yapmak icin kullanilir
print('4:', '\n', 'Oyun ', ' sahasi ', ' kapali')                        #   " \n " enter yapmak icin kullanilir
print('5:', ' Oyun ', ' sahasi ', ' kapali', '\b\b')                     #   " \b " sola dogru bir satir siler
print('6:', 'Merhaba Arkadas nasilsin \r Zalim Dünya!')                  #   " \r " kendinden sonraki yazinin satir basina gidip yazmasini saglar

# %% [markdown]
# ### **TRUE ve FALSE IFADELER**

# %%
print('1:', False or True)                 #    " or " toplama islemi gibidir. Sona kadar True arar ve ilk True'da yazar.
print('2:', True and False)                #    " and " carpma islemi gibidir. icinde False arar ilk False'da yazar
print('3:', None or '')                    #    ici bos tirnaklar 0 kabul edilir
print('4:', 'a' and not True)              #    " not " ifadesi tam tersine cevirmek icin kullanilir
print('5:', 0 or 1)                        #    0 ve 1 False ve True olarak cevrilir 
print('6:', True * True)                   #    carpim islemi gibi yazdirabiliriz. True: 1,  False: 0  
a, b = 5, 7
print('7:', id(a), id(b))                  #    tanimli ifadenin bellek adreslerini yazar
print('8:', a is b)                        #    Bellek adresleri ayni mi diye bakar ona göre True veya False yazar
print('9:', 'ali' or False)                #    Tirnak icine yazilan her ifade True kabul edilir
                                           #    Islem sirasi: parantez > not > and > or
                                           #    '', "", {} bu degerler False kabul edilir

# %% [markdown]
# ### **MATEMATIKSEL ISLEMLER**

# %%
                                       #    |"+=" --> "x = x + n"| ## | "-=" --> "x = x - n" | ## | "*=" --> "x = x * n" |
print('1:', 36 // 5)                   #    bölme islemi yapar tam sayi verir
print('2:', 36 / 5)                    #    bölme islemi yapar küsuratli verir
print('3:', 36 + 5)                    #    toplama islemi yapar
print('4:', 36 - 5)                    #    cikarma islemi yapar
print('5:', 36 % 5)                    #    bölme isleminden kalani verir
print('6:', 2 ** 5)                    #    üssünü alma islemidir
print('7:', 9 ** 0.5)                  #    Karekök alma yöntemidir. Kesirli olarak verir
print('8:', int(5.0))                  #    " int " tam sayi yapar
print('9:', str(5.0))                  #    " str " metin yapar
print('10:', float(5))                 #    " float " kesirli sayi yapar
print('11:', complex(3.45j))           #    " complex " karisik sayi yapar
print('12:', bool(1))                  #    " bool " icindeki ifadenin True veya False karsiligini verir
print('13:', 5 == 5)                   #    denktir isareti
print('14:', 6 != 5)                   #    denk degildir isareti
print('15:', 6 is 5)                   #    esittir anlami vardir
print('16:',round(16.65754, 2))        #    sayiyi en yakin degere yuvarlar. Virgülden sonraki sayi noktadan sonra kac basamak olacak belirler. Olmazsa tam sayi verir.
print('17:', round(123_675, -3))       #    virgülden sonra negatif sayi girilirse girilen kadar onluk sisteme yuvalar ve sifir "0" ekler
print('18:', bin(12))                  #    sayinin ikili sistemdeki karsiligini verir
print('19:', oct(12))                  #    sayinin sekizli sistemdeki karsiligini verir
print('20:', hex(12))                  #    sayinin onaltili sistemdeki karsiligini verir
print('21:', pow(3, 2))                #    sayinin üssünü almak icin kullanilan fonksiyondur
a = 5
print('22:', eval('pow(a,2)'))         #    icine girilen "a" degeri tanimli ise matematiksel islem yapar. Tirnak icerisinde girilmesi lazim

# %% [markdown]
# ### **DILIMLEYEREK YAZDIRMA KULLANIMI**

# %%
city = 'Dresden'

print('1:', city[1:])                 #   belirledigimiz yerden itibaren yazmaya basla
print('2:', city[:4])                 #   belirlenen yere kadar yazar (sondaki sayi dahil degil)
print('3:', city[::2])                #   tamamini 2 satir atlayarak yazar
print('4:', city[-5:])                #   normal yazar sadece eksili ifadeler ile calisilmis oldu
print('5:', city[::-1])               #   tamamini tersten yazar
print('6:', len(city))                #   icinde kac tane karakter var onun sayisini verir
print('7:', type(city))               #   tanimli ögenin tipini verir

# %%
cumle = 'Dun %d kilo %s aldim ama %.2f grami bozuktu ' % (5, 'tavuk', 50)             #   " % " isareti ile ifadeleri yandan birlestiriyoruz
print('1:', cumle)                                                                    #   " %d " : integer, " %s " : string, " %.f " : float

print('2:', '%.15s' % cumle)                                                          #    cumleyi istedigimiz yere kadar yazdirdik

sayi = 12345
print('3:', '%.7d' % sayi)                                                            #    7 digitlik bir sayi dizisi olusturdu kalan yerlere " 0 " ekler     

print('4:', '%(kilo)d kilo %(meyve)s aldim' % {'kilo': 3, 'meyve' : 'portakal'})      #   " % " ifadelerine atamalar yaptik ve "{} " icinde tanittik

print('5:', format("Welcome", "10s"), end = '#')                                      #   "10s" ile string ifadenin uzunlugunu belirler. Sonuna bosluk ekler.
print('6:', format(111, "4d"), end = '#')                                             #   "4d" ile integer sayinin uzunlugunu belirledik. Basina bosluk ekler.
print('7:', format(924.656, ".2f"))                                                   #   ".2f" noktadan sonraki karakter sayisini belirler. (son sayi > 5 ise yukari yuvarlar)

# %% [markdown]
# ### **FORMAT YÖNTEMI KULLANIMI**

# %%
meyve = 'Karpuz'
miktar = 5
print('1:', 'Ali {} kiloluk {} aldi'.format(miktar, meyve))                            #   " {} " ve format ile tanimli ögeyi cagirabiliriz

print('2:', 'hava {0} ama {1} hep {isi} dereceydi'.format(36, 'evimiz', isi = 24))     #   yeni tanimlamalar yapilabilir

print('3:', '{2} {3} {1} {0} {4}'.format('ali', 22, 'yasina', 'geldigi', 'zaman'))     #   istedigimiz sirada yazdirabiliriz

yeni = f'satilan {meyve}un {miktar} kilosu cöpe gitti'                                 #   " format " ile aynidir yazim farki vardir sadece " {} " olmasi gerekir
print('4:', yeni)

yazi = '%d kilo %s satin aldim' % (3, 'elma')                                          #   " % " isareti ile belirli bir tanim yapabiliriz.
print('5:', yazi)                                                                           #   %d: int,  %s: string,  %f: float,  %a: ASCI

num = 3.1456789
print('6:', 'Pi sayisi: {:07.3f}'.format(num))                                         #   ilk sayi kac karakter olacagini, ikinci sayi nokta sonrasi karakter sayisini belirler

num2 = 9876543214
print('7:', f'{num2:,}')                                                               #    verilen sayiyi parasal deger cinsinden gösterir ve ayirir.

# %% [markdown]
# ### **LIST FORMATI KOD KULLANIMLARI**

# %%
matrix = [
          [1,2,3,4],
          [5,6,7,8],
          [9,1,2,3],
         ]                                                         
nummer = [2, 4, 9, 13, 1, 3, 21, 3]                              #   Köseli parantez icinde liste formati belirlenir.
num = [1, 2, 2, 3, 3, 3, 4, 4, 4, 4]
ulke = ('Paris', 'Italya', 'Prag')                               
yeni_list = [ulke]                                               #   Liste icine almanin bir diger yoludur. Liste icindekileri tek bir karakter olarak ele alir.
dil = [['Deutsch',['Englisch', 'Türkisch'], ['Italianisch']]]
sehir = ['Berlin', 'Köln', 'Dresden', 'Frankfurt']               #   Köseli parantez ile liste formatinda yapmis olduk
plaka = [35, 'KL', 'D', 15]
nums = list(range(1,30,2))                                       #   Verilen degere kadar sayi uretir. Sondaki rakam kacar artacagini belirler.
satir = list(zip(*matrix))                                       #   " zip " komutu iki listeyi indisleri uzerine birlestirir. en kücük listeyi baz alir.
birles = matrix[0] + matrix[1] + matrix[2]                       #   listeleri birlestirme yapar
a, b, c = matrix                                                 #   Liste birlestirmenin bir baska yolu
new_list = sorted(dil)                                           #   Yeni bir liste olusturur ve siralar. (list, string, tuple, dict, set ile kullanilir)
ulke_yeni = list(ulke)                                           #   bu sekilde de liste formatina cevirmis oluruz  
sehir.append('Ankara')                                           #   Liste sonuna istedigimiz kelimeyi(1 kelime) veya listeyi ekler (ic-ice listede aynen ekler)
plaka.extend(sehir)                                              #   Parantez icindeki listeyi digerinin icine aktarir ve sona ekler. (ic-ice ise en disi listeden cikarir ekler)
sehir.insert(1, 'Izmir')                                         #   Liste icine istedigimiz konuma ekleme yapar (konum belirtmek zorunlu)
nummer.pop(1)                                                    #   Verilen konumdaki degeri bulur ve siler (sayi verilmezse son karakteri siler)
sehir.remove('Köln')                                             #   Liste icinde istedigimiz kelimeyi silmeye yarar (sadece 1 kelime siler)
sehir.sort()                                                     #   ASCII tablosuna göre siralar. Listenin sadece görünümünü degistirir.(sadece list ile kullanilir)
sehir.reverse()                                                  #   Tersten baslayarak yazdirir
#ulke_yeni.clear()                                               #   Listenin icini tamamen siler
print('1:', len(ulke))                                           #   Liste icindeki karakterlerin sayisini verir
print('2:', dil[0][1][1])                                        #   Her köseli parantez ile listenin icine girilir
ulke_yeni[1] = 'Amerika'                                         #   Listenin icinden istedigimiz yeri degistirme
print('3:',sehir, '\n' + '4:', ulke_yeni) 
print('5:', type(ulke), '\n' + '6:', yeni_list, len(yeni_list))           
print('7:', ''.join(ulke))                                       #   " join " komutu ile liste tekrar " string " yöntemine dönüstürülür. '' icine yazilanlari araya ekler    
print('8:', dir(list))                                           #   " dir " komutu ile parantez icindeki kodun calisma bilesenleri listelenir. "__" isareti olmayanlar önemli
print('9:', new_list, '\n' + '10:', satir) 
print('11:', birles, '\n' + '12:', a+b+c)
print('13:', *plaka)                                             #   " * " köseli parantezden ve virgülden kurtarmak icin kullanilir.
print('14:', nummer, sum(nummer))                                #   " Sum " liste icindeki sayilari toplamak icin kullanilir.
print('15:', nums)
print('16:', min(nummer))                                        #   Liste icindeki en kücük degeri bulmak icin kullanilir
print('17:', max(nummer))                                        #   Liste icindeki en büyük degeri bulmak icin kullanilir
print('18:', max(num, key = num.count))                          #   "key" degiskeni ile neyin max degeri bulacak tanimlanir. (burada max tekrar eden buldu)
print('19:', min(ulke, key = len))                               #   karakter sayisina göre en kücük kelimeyi bulur
print('20:', list(enumerate(sehir,1)))                           #   Verilerin konumunu gruplayarak listeler. (start=1 ile baslangic degeri verilir)

name, num, bos = ['ali', 'veli'], ['can', False], [] 
print('21:', all(name), all(num), all(bos))                      #   Yinelenebilir yada bos degerlerde True verir. "And" mantigi ile calisir. 
print('22:', any(name), any(num), any(bos))                      #   Yinelenebilir degerlerde True, bos listede False verir. "Or" mantigi ile calisir. 

number = iter([256, 'Ahmet', 12])                                #   Yinelenebilir nesneler "iter()" fonksiyonu ile yineleyici döndürülür
print('23:', next(number, 'dur'))                                #   "next()" iterable nesneler arasindan ilk buldugundan baslayarak her printte sonrakini gösterir
print('23:', next(number, 'dur'))                                #   Nesnelerin döndürülebilmesi icin "iter()" fonksiyonu ile kullanilmasi gerekir
print('23:', next(number, 'dur'))                                #   Bu komut "list, set, tuple, dict" ile birlikte kullanilabilir
print('23:', next(number, 'dur'))                                #   Sonda verilen deger "dur" yinelenebilir nesneler bitince msj vermesi icindir

# %% [markdown]
# ### **TUPLE (DEMET) FORMATI KULLANIMLARI**

# %%
                                                        #   *** icerigi degistirilemez, Listelerden daha hizli calisirlar ve az yer kaplarlar ***
t = ()                                                  #   parantez icine alinanlar ve virgül ile ayrilanlar "tuple" formatidir
t1 = tuple()                                            #   "tuple" sarmalina alarak format degistirilebilir
t2 = 'p', 'y', 't', 'h', 'o', 'n'                       #   parantez olmasada virgül (,) ile ayrildigi icin "tuple" formatindadir
t3 = 1, 2, 3, 4                                         #   sayilarda virgül ile ayrilarak "tuple" formatinda olurlar
t4 = ('python')                                         #   parantez icinde olsada virgül ile ayrilmadigi icin "string" formatindadir
t5 = ('a', 'b')                                         #   virgül ile ayrildi ve parantez icinde oldugu icin "tuple" formantindadir
t6 = ['Mehmet']                                   
t7 = tuple(t6)                                          #   listeler de "tuple" sarmali icine alinabilir.
t8 = t2, t3, t5                                         #   ic ice tuple olusturmak icin kullanilir
a, b, c = t8                                            #   burada tuple icinden teker teker atama yapilabilir
print('1:', 't: ', type(t), '\nt1: ', type(t1))
print('2:', 't2: ', type(t2), '\nt3: ', type(t3))
print('3:', 't4: ', type(t4), '\nt5: ', type(t5))
print('4:', t7)                                         #   "tuple" ciktilari parantez icinde ve virgül ile ayrilmis olarak verir
print('5:', *t5)                                        #   " * " isareti disdaki parantezleri ve virgülleri kaldirir
print('6:', t8)
print('7:', t8[0])                                      #   ic ice tuple formatinda " [] " isareti ile iceri girilip istenilen yazdirilabilir
print('8:', [1, 2, 3], [3, 4], [5][0])                  #   ic ice girerek yazdirma yaptik
print('9:', b)
print('9:', tuple(enumerate(t2)))                       #   tuple formatinda da calisir ve degerlerin sirasini verir. start verilmezse "0" dan baslar

# %% [markdown]
# ### **DICT(SÖZLÜK) FORMATI KOD KULLANIMLARI**

# %%
form = {'personal':{                                                            #   Süslü parantez "{}" ile "dict" olusturuyoruz. Bir nevi sözlük gibi düsünülebilir
                   'erkek':                                                     #   Her yeni süslü parantez ile biraz daha iceri girilir
                            {'ali': {'sname': 'Kurt', 'age': 25},               #   Her süslü parantezden sonra virgül gelmelidir.
                             'veli':{'sname': 'Nergiz', 'age': 32},             #   tanim aralarinda " : " kullanilmalidir
                            },                                                  #   her acilan süslü parantez kapatilmalidir.
                   'bayan':
                            {'ayse': {'sname': 'Ulu', 'age': 21},
                             'umran': {'sname': 'Demir', 'age': 19}
                            },
                    },    
       }
ad = [ 'one', 'two', 'three', 'four', 'five']
no = [1, 2, 3, 4, 5]
mix_szlk = {'animal': 'dog', 'planet': 'neptun', 'number': 40, 'good': True}
my_dict = {1: 'bir', 2: 'iki', 3: 'üc', 4: 'dört', 5: 'bes', 6: 'alti'}
szlk_atama = dict(one = 1, two = 2, three = 3)
mix_szlk['land'] = 'Italia'                                                     #   dict icerisine yeni key ve deger eklemesi yaptik   
mix_szlk['planet'] = 'Mars'                                                     #   dict icersindeki bir degeri degistirdik
mix_szlk.update({'good': False})                                                #   dict icindeki verilerde degisiklik yapabiliriz. Deger yoksa en sona ekleme yapar.
#mix_szlk.clear()                                                               #   komut ile liste icini tamamen silebiliriz
grocer = dict(meyve = 'Armut', sebze = 'Domates')                               #   "dict" sarmalina alinabilir. (key '' olmadan ve "=" ile kullanilir)
sozluk = dict(zip(ad, no))                                                      #   zip ile birlestirerek farkli formatlari dict formatina cevirebiliriz
sozluk_list = list(sozluk.items())                                              #   "list" sarmalina alarak grup halinde yazdirma yapabiliriz
print('1:', form['personal']['erkek']['ali']['sname'])                          #   Burada ic ice girerek istedigimiz kisinin istenilen bilgilerini yazdirabiliriz
print('2:', form['personal'].items())                                           #   Icerideki bütün anahtar kelimeleri ve degerleri gösterir
print('3:', *form['personal']['erkek'].keys())                                  #   sadece icerideki anahtar kelimeleri gösterir. * ile bastaki tanimdan ve tirnaktan kurtarir
print('4:', form['personal']['bayan']['umran'].values())                        #   sadece icerideki degerleri gösterir
del form['personal']['erkek']                                                   #   komut ile icerideki istenilen veriler silinebilir
print('5: silindi..:', mix_szlk.pop('number', 'Sözlükte yok'))                  #   icine girilen degeri siler eger yoksa mesaj yazdirabiliriz.
#print('6: sildik..:', mix_szlk.popitem())                                      #   son eklenen degeri siler, eger ekleme yoksa son degeri siler.
print('7:', form['personal'])
print('8:', sozluk, '\n9:', grocer)
print('10:', sozluk_list, '\n11:', mix_szlk)
print('12:', szlk_atama)
print('13:', 'animal' in mix_szlk)                                              #   verilen kelimeyi "key" icinde arar. True ve False deger verir ("in" icinde )
print('14:', 'dog' not in mix_szlk.values())                                    #   verilen kelimeyi "value" icinde arar. True ve False deger verir ("not in" icinde degil)
rakam = 2
print('15:', my_dict.setdefault(7, 'icinde yok'), my_dict)                      #   icinde yoksa mesaji yazdirir, ayni zamanda sözlüge degeri ve mesaji ekler.
print('16:', my_dict.get(rakam, 'rakam bulunamadi'))                            #   key degeri varsa karsiligini verir yoksa istedigimiz yaziyi veya "None" yazar.
                                                                                #   --> get(key(True), 'sözlükte yok'(False)) <-- mantigi ile calisir

# %% [markdown]
# ### **SET (KÜME) FORMATI KOD KULLANIMLARI**

# %%
a = {'orange', 'blau', 'red', 'blau', 'rose'}                     #   "{}" veya "set" sarmalina alarak olusturulabilir. Sirasiz bir sekilde yazdirir.
flower = 'rose', 'orkhide', 'rose', 'violet', 'red'                                                        
b = set(flower)                                                   #   "set" küme icindeki elemanlarin hepsinden birer tane gösterir. tekrarlama olmaz
bos_kume = set()                                                  #   bos küme icin "set" sarmalina alinmali. sadece "{}" olursa dict olarak algilar
c = set('philadelphia')                                           #   icinde tek öge varsa hepsini ayirir, tekrarsiz ve sirasiz yazar. (icine tek deger alir)
d =set('dlia')
e = {'dolphin'}                                                   #   icindeki ögeleri tek olarak algilar ve yazar.
print('1:', a.difference(b))                                      #   Iki kümeyi karsilastirir sadece "a" da farkli olanlari yazar (Fark)
print('2:', b.difference(a))                                      #   Iki kümeyi karsilastirir sadece "b" de farkli olanlari yazar (Fark)
print('3:', a - b)                                                #   Iki kümeyi karsilastirir sadece farkli olanlari yazar

print('4:', a.union(b))                                           #   Iki kümenin birlesimini verir. Tekrar olanlari yazmaz (Birlesim)
print('5:', a | b )                                               #   Iki kümenin birlesimini verir. Tekrar olanlari yazmaz (Birlesim)

print('6:', a.intersection(b))                                    #   Sadece iki kümede de olanlari yazar (Kesisim)
print('7:', a & b)                                                #   Sadece iki kümede de olanlari yazar (Kesisim)
bos_kume = frozenset(bos_kume)                                    #   "frozenset" bu küme formatinin icine ekleme yapilamaz
a.remove('orange')                                                #   Küme icerisinden istenilen degei siler. Deger kümede yoksa hata verir.
new = a.copy()                                                    #   A kümesindeki bütün elemanlari yeni kümeye kopyalar
a.add('yellow')                                                   #   Küme icerisine ekleme yapar
print('8:', a)
print('9:', 'red' in b)                                           #   Kümenin icinde istedigimiz kelime var mi diye bakar
print('10:', 'purple' not in b)                                   #   Kümenin icinde istedigimiz kelime yok mu diye dogrulama yapilir
print('11:', c)
print('12:', e)
print('13: silindi..:', c.pop())                                  #   küme ile kullanimda deger istemiyor. Rastgele silme yapiyor
c.discard('p')                                                    #   küme icinde istenilen degeri siler. Deger bulamazsa hicbir sey yapmaz.
print('14:', d.issubset(c))                                       #   d kümesi c kümesinin alt kümesi mi diye sorgular ve True-False verir
print('15:', c.issuperset(d))                                     #   c kümesi d kümesini kapsar mi diye sorgular ve True-False verir

# %% [markdown]
# ### **IF ve INPUT KOMUT KULLANIMLARI**

# %%
score = int(input('Puaninizi girin..: '))       #   kullanici tarafindan girdi yapilmasini saglar. aksi belirtilmedikce "string" ifade tanimlar
if score >= 90:                                 #   her zaman bir sarta baglidir ve satir sonunda " : " isareti gelir. Belirtilmezse ilk "True" mu diye bakar. 
    if score >= 95:                             #   ic ice if komutu verilerek dallanma islemi yapilabilir
        derece = 'A+'                           #   if tanim ve yazdirmada her zaman bosluk birakilir ve icten yazmaya baslanir
    else:
        derece = 'A'
elif score >= 80:                               #   "elif" bu komutun "eger öyle degil böyleyse" anlami vardir.
        derece = 'B'
elif score > 70 or score == 70:                 #   "or" komutu ile ikisinden birisi dogru ise anlami verilebilir
        derece = 'C' 
elif score >= 50 and score <= 60:               #   "and" komutu ile iki degerde dogru ise islemi yap komutu verdik                  
        pass                                    #   "pass" komutu herhangi bir islemi pas gecmek icin kullanilir.
elif score == 40:
    raise  Exception('Bu nasil not..:(')        #   "raise" istenmeyen bir giriste hata verdirmek icin kullanilir (TypeError, ValueError)
else:                                           #   bu komutun "bunlarin hicbiri degilse" anlami vardir.
    derece = 'Gecemediniz'
print('Dereceniz..: ', derece)
                                                #   if n <= 1:  <-- Bu iki komut ayni islemi yapar -->  if n in {0,1}:
sayi = []
for i in range(10):
    if i % 2 == 0:                              #   Cift sayilari listeye ekler, tek sayilarin karesini listeye ekler.
        sayi.append(i)
    else:
        sayi.append(i**2)
print('1:', sayi)

yeni = [i if i % 2 == 0 else i**2 for i in range(10)]           #   for, if ve else komutlarini tek satirda yazdik. Siralama önemli.
print('2:', yeni)

sayi = 50
print('3:','Sayi 50' if sayi == 50 else 'Sayi belirsiz')        #   Tek satirda if ve else komutu kullanimi

# %% [markdown]
# ### **FOR DÖNGÜ KOMUT KULLANIMI**

# %%
#  For döngüsü genellikle liste, tanımlama grubu, küme ve sözlük gibi çeşitli koleksiyon türlerinin öğelerini yinelemek için kullanılır.

season = ['spring', 'summer', 'autumn', 'winter']
for a in season:                                    #   liste icinde gezerek hepsini teker teker yazdirir
    print('1:', a)                 

dongu = list(range(1,8))                            #   " range " istenilen rakama kadar dongu olusturur. (baslangic, bitis, kacar adim) olarak verilebilir
para = 1000
for i in dongu:                                     #   liste icinde döngü yapar yada sayi üretir bir kosula bagli degildir. burada icindekiler kismi tanimlaniyor
    para += para * (0.07)
    i += 1                                          #   burada "i" tanimlamaya gerek yok kendisini otomatik olarak basliyor
print('2:', int(para), '$')                         #   print bosluklari önemli ona göre tüm döngüyü yazar ya da sonucu yazar
print('3:', dongu)

who = ['Ich bin ', 'Du bist ']
mood = ['froh', 'angry', 'müde']
for i in who:                                       #   ic ice for döngüsü olusturulabilir. 
    for c in mood:                                  #   dis döngü baslar ilk degerini alir ic döngüyü bitirir sonra dis döngü siradaki degeri alir
        print('4:', i, c)

text = ['eins', 'zwei', 'drei']
num = [1, 2, 3, 4]
for x, y in zip(text, num):                         #   "zip" komutu ile sütunlari birlestirir. en kücük listeyi baz alir.
    print('5:', x, ':', y)                          #   döngü icerisinden birden fazla atama yapilabilir

print('6:', *range(16,0,-2))                        #   verilen degere göre tersten sayi üretebiliriz.

for i in "pythontr":
    if i == "t":
        continue                                    #   burada eger kosul saglaniyorsa alttaki komutlari atlar ve basa döner. While ile de kullanilir
    print(i, end=' ')

cift = []
for i in range(12):
    if i % 2 == 0:
        cift.append(i*i)                            #   cift sayilarin karesini listeye ekleme yaptirdik 
print('\n8:', cift)

yeni = [i*i for i in range(12) if i % 2 == 0]       #   for ve if komutlarini tek satirda kisaltarak yazdik. atama yapamk icin "[]"" yada "liste" formatinda olmali.
print('9:', yeni)                                   #   asil islem basa yazilir sonra tüm satir bosluklar ile yazilir

# %% [markdown]
# ### **WHILE DÖNGÜ KOMUT KULLANIMI**

# %%
liste = ['a', 'b', 'c', 'd', 'e']
a = 0
while a < len(liste):                               #   bu komut kosula baglidir. True ve False ile calisir ve döngü kurar. Ilk kosul olarak True mu diye bakar. 
    print('1: {} karesi..: {}'.format(a, a**2))
    a += 1                                          #   her seferinde listeye geri dönmesini ve sayiyi arttirmasini sagladik.

sayi = 45
while True:                                         #   True ifadesi ile sonsuz döngü baslattik
    tahmin = int(input('sayi kac..: '))
    if tahmin < sayi:                               #   döngü icerisinde "if" ifadesi ile yeni kosullar olusturulabilir
        print('2: daha büyük')
    elif tahmin > sayi:
        print('3: daha kücük')
    else:
        print('4: sayiyi buldun')
        break                                       #   döngüden cikmak icin kullanilir

yas = input('Yasinizi girin..:')
while not yas.isdigit():                            #   "isdigit" komutu sadece rakam girilmesine izin verir. String kabul etmez.
    yas = input('Lütfen rakam olarak girin..: ')
print('5: Bravo yasin :', yas)

# %% [markdown]
# ### **DEF FONKSIYONU KULLANIMI**

# %%
b = 5                                     #   burada "b" global bir degiskendir her yerden ulasilabilir ve cagirilabilir
def deger():                              #   "def" komutu ile fonksiyon baslatilir ve fonksiyona bir isim atanir
    global b                              #   fonksiyondaki "b" degiskeninin her yerden cagirilabilir yapar. Icerideki degisiklikleri globala yansit anlami da vardir.
    b = 7                                 #   fonksiyon icinde deger atamasi yapar
    #print(b)                             #   fonksiyon icindeki "print" sadece fonksiyon icindeki ve yerel degiskenleri yazdirmak icin kullanilir
deger()                                   #   fonksiyonun calistirilmasi disarida fonksiyon isminin yazilmasi ile mümkün
print('1:', b)                            #   fonksiyon disinda oldugu icin sadece global degiskenlerini yazdirir

def sayi():
    s = 5
    return s                              #   "return" komutu ile "sayi()" fonksiyonu bir degere atama yapilabilir ve print() icinde yazdirilabilir
son = sayi()                              #   "return" komutu sayesinde fonksiyon ismi kullanarak sonucu bir degiskene atama yaptik
print('2:', sayi())                       #   "return" fonksiyon ismi ile direk yazdirma yaptik. (Parantezler önemli)
print('3:', son)                          #   fonksiyon cagrilirken kullanilan parametrelere argüman denir

def coklu(sayi, mesaj = 'Hallo', dongu = 3):                #   fonksiyon icerisinde degerler parametredir. Burada otomatik olarak tanimladik.
    print('4:', sayi, 'kez', mesaj, dongu, 'e kadar')       #   "sayi" parametresi konumsal argümandir ve ilk önce yazilmalidir.
coklu(5)                                                    #   diger degerler girilmese bile tanimli olanlari otomaik olarak yazar
coklu(4, 'Naberr')                                          #   sirasiyla fonksiyon icindeki tanimli degere yeni deger atanabilir
coklu(mesaj='Gece', sayi=8, dongu=10)                       #   sirasiz olarak yeni degerler atanabilir. Birine atanirsa digerine de deger atanmali yoksa hata verir

def meyveler(*fruit):                                       #   " * " kac tane girdi olacagini bilmedigimiz durumlarda kullanilir              
    print('5:', fruit)                                      #   *args (arguments) --> keyfi sayida konum argümani tanimlamak icin kullanilir
hazir =['Cilek', 'Karpuz', 'Erik'] 
meyveler('Portakal', 'Elma', 'Armut')                       
meyveler(*hazir)                                            #   Tanimli bir liste icerisinden buraya deger almak icin de " * " kullanilabilir

def hayvan(**animal):                                       #   " ** " kac adet anahtar kelime ve argüman girilecegini bilmedigimiz durumlarda kullanilir
    for i, k in animal.items():                             #   **kwargs (keyword arguments)  --> keyfi sayida anahtar kelime tanimlama icin kullanilir
        print('6:', k, 'bir', i)  
aile = {'y': 'Murat', 'x': 'Ufuk'}                          
hayvan(etobur='Aslan', otobur='Fil', hepobur='Ayi')         
hayvan(**aile)                                              #   Tanimli bir sözlük icerisinden buraya deger almak icin de " ** " kullanilabilir

number = [1,2,5,8,9,11,12,16,20,25,37,38]
def cift(x):
   return x % 2 == 0                                        #   Çağırılan fonksiyonun döndürdüğü değerin true olduğu durumlara göre liste döndürür
print('7:', list(filter(cift, number)))                     #   liste üzerinde filtreleme yapmamizi saglar. **filter(fonk.adi yada kosul, liste adi)**
                                                            #   "filter" icerisinde True ve False degeri döndürecek kosul olmali
def kare(sayi):
    return sayi * sayi
sayi = range(1,10)                                          #   "map" listenin tüm elemanlarini tek tek "kare" fonksiyonuna gönderir ve geri döndürür.
print('8:', list(map(kare, sayi)))                          #   birden fazla liste alabilir. **map(fonk. adi, liste adi, liste adi)**
                                                            #   ciktiyi alabilmek icin "list()" sarmalina alinmalidir
def ana():
    x = 'Dis katman'
    def icten():                                            #   en icteki fonksiyona disaridan cagrilarak dogrudan ulasilamaz
        nonlocal x                                          #   en icte tanimlanan degiskeni yerel olmaktan cikardi ve bir üst fonksiyona genisletti
        x = 'Ic katman'
        print('9: Icte: ', x)
    icten()                                                 #   ic ice tanimlanan fonksiyonlarda cikti alabilmek en icten baslayarak kapatmak lazim
    print('9: Dista: ', x)
ana()

def position(konum, /):                                     #   "/" öncesinde konumsal degisken girilmesi zorunludur. Sonrasi fark etmez
    print(konum)
def position(*, keyword=5):                                 #   "*" sonrasinda keyword degisken girilmelidir. Öncesi fark etmez
    print(keyword)

def faktoriyel(x):                                          #   fonksiyon kendini cagiriyorsa veya kendine atifta bulunuyorsa bu fonksiyon recursive(özyinelemeli) fonksiyondur
    if x <= 1:                                              #   islemciye cok fazla yük bindiren bir fonksiyondur
        return 1
    else:
        return x * faktoriyel(x-1)                          #   burada fonksiyon kendisini cagiriyor ve islem yapiyor
print('10: ', faktoriyel(5))

import keyword
print('11', keyword.kwlist, end=' ')                        #   keyword listesini görmek icin kullanilir. Bu listedekiler degisken ismi olarak kullanilamaz
print('12: ', bool.__doc__)                                 #   "__doc__" önceden tanimli fonksiyonun görevini ögrenmek icin kullanilir
help(pow)                                                   #   "help" önceden tanimli olan fonksiyonun özelliklerini detayli olarak görmemizi saglar.

# %% [markdown]
# ### **LAMBDA FONKSIYONU KULLANIMI**

# %%
print('1:', (lambda x: x**2)(3))                                    #   "x" degiskenine parantez icerisinde deger verebiliriz
print('2:', (lambda x, y: (x + y) / 2) (9, 7))                      #   birden fazla degiskene parantez icerisinde deger verebiliriz

tek_cift = (lambda x: 'cift' if x % 2 == 0 else 'tek')              #   bir degiskene deger olarak atama yapabiliriz
print('3:', tek_cift(16))                                           #   print esnasinda parantez icinde degiskenlere deger atayabiliriz
print('4:', (lambda x: 'cift' if x % 2 == 0 else 'tek')(16))        #   direk print komutunun icerisinde yazilarak deger verilebilir

sayi = [2, 3, 4, 5, 6, 7, 8, 9]
sonuc = list(map(lambda x: x**2, sayi))                             #   "map" fonksiyonu icinde lambda tanimlanabilir. Sirali bir atama oldugu icin "list" sarmalinda olmali
print('5:', sonuc)                                                  #   **map(fonk. adi, liste adi, liste adi)**
print('6:', list(map(lambda x: x**2, sayi)))                        #   yazdirma islemi sirasinda da "list" sarmalina alinarak yazdirma yapilabilir

print('7:', list(filter(lambda i: i % 2 == 0, sayi)))               #   "filter" komutu listedeki ögelerden True olanlari döndürür ve ciktisini verir
                                                                    #   "filter" icerisinde True veya False döndürecek kosul olmali. **filter(fonk.adi yada kosul, liste adi)** 
liste = [None, '', 0, False, 'Fresh', 'Ahmet', None, 'Veli']
print('8:', list(filter(bool, liste)))                              #   Eger fonksiyon bool ise filter(), False ya da None döndüren elemanları listeden kaldırır.
print('9:', list(filter(None, liste)))                              #   Eger fonksiyon None ise filter(), False ya da None döndüren elemanlari listeden kaldirir.

sesli = ['a', 'e', 'i', 'o', 'u']
harfler = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']
s = filter(lambda k: True if k in sesli else False, harfler)        #   "filter" fonksiyonu icerisinde if ile True tanimlamasi yaptik
print('10: Sesli harfler:', list(s))                                #   liste icerisindeki sesli harfleri yazdirdik

def carp(n):
    return lambda a: a * n                                          #   def fonksiyonu icerisinde lambda fonksiyonu tanimlamasi yaptik
kere = carp(3)                                                      #   def fonksiyonu icerisindeki "n" degiskenine deger atadik     
print('11:', kere('Ufuk '))                                         #   lambda fonksiyonundaki "a" degiskenine deger atadik

from functools import reduce                                        #   "reduce" fonksiyonu kullanilmadan önce import edilmelidir. 
number = [11, 23, 9, 34, 2, 64]                                     #   "reduce" ayni anda iki tane degeri alir ve isleme sokar, sonucu hafizasinda tutar ve yeni degerler ekler
sonuc = lambda x, y: x if x > y else y                              #   lambda fonksiyonu ile yapilacak olan islemi tanimladik. En büyük sayiyi bulma
print('12: En büyük sayi:', reduce(sonuc, number))                  #   **reduce(fonk. adi, liste adi)**

print('13:', reduce(lambda a, b: a + b, range(101)))                #   "reduce" icin iki tane degisken olmalidir. 
print('14:', reduce(lambda x,y: x+y, [[1,2,3],[4,5],[6,7,8]]))      #   "reduce" ilk degerleri alir toplar, x = toplam deger olur ve y degiskenine yeni deger vererek devam eder.

# %% [markdown]
# ### **MODÜLLER**

# %%
### Önceden olusturdugumuz bir ".py" uzantili python dosyamizi, icindeki fonksiyonlari ve degiskenleri projeye import ederek kullanabiliriz.
### Proje ve önceden olusturulan ".py" uzantili dosya ayni klasör icerisinde olmali

import dosyam()                                 #   modülümüzü projeye import ettik
dosyam.fonksiyonum()                            #   modülün icerisindeki fonksiyona ulastik
print(dosyam.sayac)                             #   modül icerisindeki tanimli bir degiskene ulastik

import dosyam as sözlük                         #   import edilen bir modüle takma isim verebiliriz
sözlük.fonksiyonum()                            #   takma isim ile modül icerisinden fonksiyona ulastik
print(sözlük.sayac)                             #   takma isim ile modül icerisinden bir degiskene ulastik

from dosyam import fonksiyonum                  #   modül icerisinden sadece istedigimiz bir fonksiyona ulastik
fonksiyonum()                                   #   sadece fonksiyon cargirdimizi icin dosyam.fonksiyonum() gibi kullanmamiza gerek yok

from dosyam import fonksiyonum as kare          #   modül icerisinden import edilen fonksiona takma isim verebiliriz
kare()                                          #   takma isim ile fonksiyonu kullanabiliriz.

from math import pi, factorial, log10           #   ayni anda birden fazla import yapabiliriz

import string
print(string.punctuation)                       #   mevcut tüm noktalama isaretlerini yazdirir
print(string.digits)                            #   tüm rakamlari yazdirir
print(string.ascii_letters)                     #   ascii tablsounda olan bütün harfleri yazdirir

import datetime
print(datetime.date.today())                    #   bugünun tarihini yazdirir
print(datetime.datetime.now())                  #   bugünün tarihini ve  su anda saat kac oldugunu yazdirir

# %% [markdown]
# ### **RANDOM KOMUTU**

# %%
import random
a = random.randint(1,20)                                        #   rastgele bir tamsayi üretmek icin kullanilir. Aralik parantez icinde belirtilir
b = random.uniform(0.5, 2.0)                                    #   rastgele bir kesirli sayi üretmek icin kullanilir. Aralik parantez icinde belirtilir
c = random.random()                                             #   0 - 1 araliginda rastgele bir sayi üretmek icin kullanilir

liste = ['ali', 'veli', 'ahmet', 'mehmet', 'celal']
d = random.choice(liste)                                        #   liste icerisinden rastgele bir kelime secer
e = random.choice(liste[0])                                     #   liste icinde kelimeler arasindan rastgele bir harf secer

f = list(range(11))
random.shuffle(f)                                               #   Listeyi karisik bir sekilde yazdirmak icin kullanilir

s = range(100)
g = random.sample(s, 3)                                         #   belirtilen liste arasindan istenilen sayi kadar rastgele sayi secer

print('1:', a)
print('2:', b)
print('3:', c)
print('4:', d)
print('5:', e)
print('6:', f)
print('7:', g)

# %% [markdown]
# ### **EMOJILER ve ASCII KARAKTERLER**

# %%
import time
print('1:', '\N{Ghost}')                          #   emojinin kendi ismi girilerek yazdirilabilir.
print('2:', '\N{shark}')
print('3:', '\N{spouting whale}')
print('4:', '\N{front-facing baby chick}')
print('5:', '\U0001F600')                         #   emojinin kodu girilerek yazdirilabilir.
print('6:', ord('@'))                             #   ASCII kodunu ögrenmek icin kullanilir
print('7:', chr(64))                              #   ASCII kod girilir karakteri yazdirir
time.sleep(2)                                     #   gecikme eklemek icin kullanilir. Saniye olarak islem yapar. *Import time* kullanilmalidir
print('8:', chr(ord('b') + 1))
